# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from random import randint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
 
def saveplot(path, ext='png', close=True, verbose=True):
    """Save a figure from pyplot.
    Parameters
    ----------
    path : string
    The path (and filename, without the extension) to save the
    figure to.
    ext : string (default='png')
    The file extension. This must be supported by the active
    matplotlib backend (see matplotlib.backends module). Most
    backends support 'png', 'pdf', 'ps', 'eps', and 'svg'.
    close : boolean (default=True)
    Whether to close the figure after saving. If you want to save
    the figure multiple times (e.g., to multiple formats), you
    should NOT close it in between saves or you will have to
    re-plot it.
    verbose : boolean (default=True)
    Whether to print information about when and where the image
    has been saved.
    """
    # Extract the directory and filename from the given path
    directory = os.path.split(path)[0]
    filename = "%s.%s" % (os.path.split(path)[1], ext)
    if directory == '':
        directory = '.'

    # If the directory does not exist, create it
    if not os.path.exists(directory):
        os.makedirs(directory)

    # The final path to save to
    savepath = os.path.join(directory, filename)

    if verbose:
        print("Saving figure to '%s'..." % savepath),

    # Actually save the figure
    plt.savefig(savepath)
    # Close it
    if close:
        plt.close()

    if verbose:
        print("Done")

# %%
wavelength = 5461
voltage = [-3.0, -2.5, -2.0, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0] #v
current = [-0.0061, -0.0052, -0.0045, -0.0038, -0.0029, 0.04869, 1.9374, 6.34, 9.28, 10.67, 11.76, 12.35, 12.75] #nA

plt.plot(voltage, current, 'o')
plt.plot(voltage, current, 'r', linewidth = 2)
plt.title('Current as a funtion of Voltage (546.1 nm light)')
plt.xlabel('Voltage (V)')
plt.ylabel('Current (nA)')
#saveplot('current_v_voltage', 'png')
plt.show()

# %%
voltage_s = [0, -.1, -.2, -.3, -.4, -.5, -.6, -.7, -.74] #V
current_s = [1.95, 1.22, 0.66, .31, .13, 0.049, 0.014, 0.002, 0.000] #nA

plt.plot(voltage_s, current_s, 'o')
plt.plot(voltage_s, current_s, 'r', linewidth = 2)
plt.title('Current as a funtion of Voltage (546.1 nm light)')
plt.xlabel('Voltage (V)')
plt.ylabel('Current (nA)')
plt.show()

V_s_5461 = -0.74 #v
print "Stopping Voltage:", V_s_5461
# Out:
# Stopping Voltage: -0.74

# %%
#@V = 0
aperture = [0, 5, 10, 15, 20, 25, 30] #mm
current_a = [0.013, .53, 2.1, 3.59, 4.58, 4.75, 4.76] #nA

plt.plot(aperture, current_a, 'o')
plt.plot(aperture, current_a, 'r')
plt.title('Current as a function of Aperture size (Voltage = 0V)')
plt.xlabel('Opening size')
plt.ylabel('Current')
#saveplot('current_v_aperture', 'png')
plt.show()

# %%
wavelengths = [546.1, 435.8, 404.7, 365.0] #nm
Vstop = [-0.74, -1.26, -1.49, -1.85] #V
#-578, -0.82
uncer = 0.8

frequencies = [] #m^-1
for i in wavelengths:
    frequencies.append((3.0*10**8)/(i*10**-9))

b, a = np.polyfit(frequencies, Vstop, 1)
x = np.arange(5*10**14, 9*10**14, 10.0**13)
y = []
for i in x:
    y.append(a + b*i)

plt.plot(frequencies, Vstop, 'o')
plt.plot(x, y, 'r')
plt.xlim(5.0*10**14, 8.5*10**14)
plt.ylim(-2.5, 0)

plt.title(r'Fit of V$_{stop}$ as a function of frequency')
plt.xlabel('Frequency (m)')
plt.ylabel('Stopping voltage (V)')
#saveplot('Vstop_fit', 'png')
plt.show()


print "Our value for Planck's constant:", -b
print a
# Out:
# Our value for Planck's constant: 4.05329772851e-15
# 1.50326778277
