# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from numpy import genfromtxt
import scipy.optimize as optimization
from scipy.optimize import curve_fit
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# TAC calibration: 192 = 3.82 118 = 2.22

# %%
74/1.6
# Out:
# 46.25

# %%
f = genfromtxt("muon_data_14May2015.mca", delimiter=',')
x = np.arange(0, len(f))

plt.plot(x, f, 'o', markersize = 1)
plt.title('mca data')
plt.xlabel('channel')
plt.ylabel('counts')


plt.show()

# %%
t = x/46.25

plt.plot(t, f, 'o', markersize = 1)
plt.title('MCA data')
plt.xlabel('Time (microseconds)')
plt.ylabel('Counts')


plt.show()
print t[1] - t[0]
# Out:
# 0.0216216216216

# %%
s = 28
fin = -44

def exponential(t, *p):
    off, N0, tau = p
    return off + N0*numpy.exp(-t/tau)

p0 = [1.0, 25.0, 1.0]

a, b = curve_fit(exponential, t[s:fin], f[s:fin], p0)
off= a[0]
N0 = a[1]
tau = a[2]
print 'offset:', off
print 'N0:', N0
print "lifetime (tau):", tau

fit = lambda t: off + N0*numpy.exp(-t/tau)

plt.plot(t, f, 'bo', markersize = 1)
plt.plot(t, fit(t), 'r')
plt.title('Fit of MCA data')
plt.xlabel('Time (microseconds)')
plt.ylabel('Counts')
plt.ylim(0, 25)

plt.show()
# Out:
# offset: -0.220703689679
# N0: 20.380834058
# lifetime (tau): 2.63180834672

# %%
f = genfromtxt("muon_data_14May2015.mca", delimiter=',')
f = f[28: -44]

# %%
print len(f)
# Out:
# 496

# %%
g = []
for i in range(len(f)):
    g.append(sum(f[i - 5 : i + 5]/5))
T = t[5: len(g) + 5]

# %%
def exponential(t, *p):
    off, N0, tau = p
    return off + N0*numpy.exp(-t/tau)

p0 = [1.0, 25.0, 1.0]

c, d = curve_fit(exponential, T, g, p0)
off_2= c[0]
N0_2 = c[1]
tau_2 = c[2]
print 'offset:', off_2
print 'N0:', N0_2
print "grouped lifetime (tau):", tau_2

fit2 = []
for i in T:
    fit2.append(off_2 + N0_2*numpy.exp(-i/tau_2))

plt.plot(T, g, 'bo', markersize = 1)
plt.plot(T, fit2, 'r')
plt.title('Fit of MCA data - Grouped averages')
plt.xlabel('Time (microseconds)')
plt.ylabel('Counts')

plt.show()
# Out:
# offset: -1.4390144644
# N0: 30.2776959565
# grouped lifetime (tau): 3.26541961634

# %%
f = genfromtxt("muon_data_14May2015.mca", delimiter=',')
f = f[28: -44]

average = sum(f)/len(f)
print "tau (average):", average
# Out:
# tau (average): 3.70161290323
